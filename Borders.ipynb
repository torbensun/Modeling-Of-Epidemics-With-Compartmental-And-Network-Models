# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
pendler=np.loadtxt("Pendler.txt")
degree_dist=np.zeros((38))

# %%
for i in range(38):
    for j in range (38):
        if(pendler[i][j]!=0):
            degree_dist[i]+=1
            degree_dist[j]+=1

# %%
degree_dist
# Out:
# array([21., 15., 18., 17., 16., 21., 16., 19., 17., 19., 14., 13., 28.,
#        10., 14., 14., 11., 10., 14.,  7.,  7., 11., 11., 12.,  9.,  9.,
#        13.,  6.,  9.,  8., 10., 12., 15., 17., 16., 21., 17., 15.])

# %%
plt.figure(figsize=(9,3.5),dpi=300)
plt.hist(degree_dist, bins=21)
plt.xlabel("Grad des Knotens")
plt.ylabel("Anzahl der Knoten")
plt.xlim(0,30)
plt.savefig("Media/degree_dist.png")
