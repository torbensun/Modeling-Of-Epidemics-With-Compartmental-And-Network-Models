# %%
from projectlib import *
import numpy as np
import matplotlib.pyplot as plt

# %%
ids = region_setup(12)[0]
cases, sird, pop = import_rki_data(ids,7)

# %%
"""Infected=(all cases)-(all recovered + all dead)"""
plt.figure(figsize=(10,8))

plt.plot(np.arange(0,444),cases[5][1],label="Summe Fälle")
#plt.plot(np.arange(0,444),(cases[5][6]+cases[5][4]),label='Summe D+R')
plt.plot(np.arange(0,444),(cases[5][6]),label='Summe R')
plt.plot(np.arange(0,444),(cases[5][4]),label='Summe D')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6ad1c7383cd4> in <module>
#       2 plt.figure(figsize=(10,8))
#       3
# ----> 4 plt.plot(np.arange(0,444),cases[5][1],label="Summe Fälle")
#       5 #plt.plot(np.arange(0,444),(cases[5][6]+cases[5][4]),label='Summe D+R')
#       6 plt.plot(np.arange(0,444),(cases[5][6]),label='Summe R')
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# ...

# %%
plt.figure(figsize=(10,8))
#plt.plot(np.arange(0,444),sird[5][0],label="S")
plt.plot(np.arange(0,444),sird[5][1],label="I")
#plt.plot(np.arange(0,444),sird[5][2],label="R")
#plt.plot(np.arange(0,444),sird[5][3],label="D")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(np.arange(0,444),cases[5][8],label="aktuell Infizierte")
plt.legend()
plt.show()

# %%
update_rki_data_arrays(12,7)
update_rki_data_arrays(38,7)

# %%
initial_compartment_distribution(38,"2020/07/24")
# Out:
# array([[ 9.98411991e-01,  6.52606620e-05,  1.49011845e-03,
#          3.26303310e-05],
#        [ 9.98495558e-01,  0.00000000e+00,  1.40509240e-03,
#          9.93499674e-05],
#        [ 9.98070320e-01,  2.20115634e-05,  1.70222757e-03,
#          2.05441258e-04],
#        [ 9.97311962e-01,  3.56503697e-05,  2.51691610e-03,
#          1.35471405e-04],
#        [ 9.98858525e-01,  2.26783082e-05,  1.08099936e-03,
#          3.77971803e-05],
#        [ 9.96012771e-01,  3.37380882e-05,  3.71118970e-03,
#          2.42300815e-04],
#        [ 9.98776429e-01,  0.00000000e+00,  1.20013126e-03,
#          2.34400638e-05],
#        [ 9.98192293e-01,  6.75778412e-05,  1.60919734e-03,
#          1.30932067e-04],
#        [ 9.98021144e-01,  6.43128175e-05,  1.87001885e-03,
#          4.45242583e-05],
#        [ 9.97674627e-01,  0.00000000e+00,  2.14649852e-03,
#          1.78874877e-04],
#        [ 9.98390097e-01, -9.99940004e-06,  1.49991001e-03,
#          1.19992800e-04],
# ...

# %%
save_initial_compartment_distribution(38, "2020/07/24")
