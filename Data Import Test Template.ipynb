# %%
from projectlib import *
import numpy as np
import matplotlib.pyplot as plt

# %%
ids = region_setup(12)[0]
cases, sird, pop = import_rki_data(ids,7)

# %%
"""Infected=(all cases)-(all recovered + all dead)"""
plt.figure(figsize=(10,8))

plt.plot(np.arange(0,438),cases[5][1],label="Summe Fälle")
#plt.plot(np.arange(0,438),(cases[5][6]+cases[5][4]),label='Summe D+R')
plt.plot(np.arange(0,438),(cases[5][6]),label='Summe R')
plt.plot(np.arange(0,438),(cases[5][4]),label='Summe D')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.plot(np.arange(0,438),sird[5][0],label="S")
plt.plot(np.arange(0,438),sird[5][1],label="I")
#plt.plot(np.arange(0,438),sird[5][2],label="R")
#plt.plot(np.arange(0,438),sird[5][3],label="D")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(np.arange(0,438),cases[5][0],label="Neuinfektionen")

# %%
cases[5][0][-1]
# Out:
# 11.0
