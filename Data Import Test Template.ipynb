# %%
from projectlib import *
import numpy as np
import matplotlib.pyplot as plt

# %%
ids = region_setup(12)[0]
cases, sird, pop = import_rki_data(ids,7)

# %%
"""Infected=(all cases)-(all recovered + all dead)"""
plt.figure(figsize=(10,8))

plt.plot(np.arange(0,444),cases[5][1],label="Summe Fälle")
#plt.plot(np.arange(0,444),(cases[5][6]+cases[5][4]),label='Summe D+R')
plt.plot(np.arange(0,444),(cases[5][6]),label='Summe R')
plt.plot(np.arange(0,444),(cases[5][4]),label='Summe D')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.plot(np.arange(0,444),sird[5][0],label="S")
plt.plot(np.arange(0,444),sird[5][1],label="I")
#plt.plot(np.arange(0,444),sird[5][2],label="R")
#plt.plot(np.arange(0,444),sird[5][3],label="D")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(np.arange(0,444),cases[5][8],label="aktuell Infizierte")
plt.legend()
plt.show()

# %%
update_rki_data_arrays(12,7)

# %%
initial_compartment_distribution(12,"2021/02/01")
# Out:
# array([[9.70766849e-01, 2.41464449e-03, 2.58069662e-02, 1.01154026e-03],
#        [9.79803571e-01, 2.04377076e-03, 1.72727015e-02, 8.79956854e-04],
#        [9.83146480e-01, 1.99571508e-03, 1.40433775e-02, 8.14427846e-04],
#        [9.67023408e-01, 1.98216056e-03, 2.99962211e-02, 9.98210351e-04],
#        [9.83913520e-01, 2.11664210e-03, 1.36069849e-02, 3.62852931e-04],
#        [9.78036505e-01, 2.01508399e-03, 1.91816367e-02, 7.66774731e-04],
#        [9.64342975e-01, 4.35047583e-03, 3.01204819e-02, 1.18606723e-03],
#        [9.70177054e-01, 3.02410839e-03, 2.58949840e-02, 9.03853626e-04],
#        [9.65280973e-01, 3.79445624e-03, 3.00489272e-02, 8.75643747e-04],
#        [9.68190084e-01, 3.26943525e-03, 2.70399189e-02, 1.50056147e-03],
#        [9.42583445e-01, 4.20974742e-03, 5.09169450e-02, 2.28986261e-03],
#        [9.71564208e-01, 3.82420639e-03, 2.38443464e-02, 7.67238899e-04]])
