# %%
from projectlib import *
import numpy as np
import matplotlib.pyplot as plt

# %%
ids = region_setup(12)[0]
cases, sird, pop = import_rki_data(ids,7)

# %%
"""Infected=(all cases)-(all recovered + all dead)"""
plt.figure(figsize=(10,8))

plt.plot(np.arange(0,444),cases[5][1],label="Summe Fälle")
#plt.plot(np.arange(0,444),(cases[5][6]+cases[5][4]),label='Summe D+R')
plt.plot(np.arange(0,444),(cases[5][6]),label='Summe R')
plt.plot(np.arange(0,444),(cases[5][4]),label='Summe D')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.plot(np.arange(0,444),sird[5][0],label="S")
plt.plot(np.arange(0,444),sird[5][1],label="I")
#plt.plot(np.arange(0,444),sird[5][2],label="R")
#plt.plot(np.arange(0,444),sird[5][3],label="D")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(np.arange(0,444),cases[5][8],label="aktuell Infizierte")
plt.legend()
plt.show()

# %%
update_rki_data_arrays(12,7)

# %%
initial_compartment_distribution(12,"2021/02/01")
# Out:
# array([[9.61452702e-01, 1.94585540e-02, 1.82403550e-02, 8.48388605e-04],
#        [9.75290244e-01, 1.23761674e-02, 1.16381390e-02, 6.95449771e-04],
#        [9.79169724e-01, 1.04334811e-02, 9.77313415e-03, 6.23660963e-04],
#        [9.49233874e-01, 2.56326158e-02, 2.42707717e-02, 8.62738947e-04],
#        [9.79793627e-01, 1.01825604e-02, 9.76679140e-03, 2.57020826e-04],
#        [9.69963900e-01, 1.51115964e-02, 1.43172178e-02, 6.07285587e-04],
#        [9.59814355e-01, 2.02053350e-02, 1.90708359e-02, 9.09474474e-04],
#        [9.58840871e-01, 2.06788194e-02, 1.97411769e-02, 7.39132638e-04],
#        [9.52774603e-01, 2.37462711e-02, 2.27766317e-02, 7.02493853e-04],
#        [9.59305965e-01, 2.05109859e-02, 1.89110495e-02, 1.27199913e-03],
#        [9.28374298e-01, 3.63678179e-02, 3.35879847e-02, 1.66989981e-03],
#        [9.64683034e-01, 1.78862568e-02, 1.69032320e-02, 5.27476743e-04]])
