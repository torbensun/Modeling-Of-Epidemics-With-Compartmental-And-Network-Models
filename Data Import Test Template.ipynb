# %%
from projectlib import *
import numpy as np
import matplotlib.pyplot as plt

# %%
ids = region_setup(12)[0]
cases, sird, pop = import_rki_data(ids,7)
# Out:
# 36110

# %%
"""Infected=(all cases)-(all recovered + all dead)"""
plt.figure(figsize=(10,8))

plt.plot(np.arange(0,438),cases[5][1],label="Summe Fälle")
#plt.plot(np.arange(0,444),(cases[5][6]+cases[5][4]),label='Summe D+R')
plt.plot(np.arange(0,438),(cases[5][6]),label='Summe R')
plt.plot(np.arange(0,438),(cases[5][4]),label='Summe D')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
#plt.plot(np.arange(0,444),sird[5][0],label="S")
plt.plot(np.arange(0,438),sird[5][1],label="I")
#plt.plot(np.arange(0,444),sird[5][2],label="R")
#plt.plot(np.arange(0,444),sird[5][3],label="D")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(np.arange(0,438),cases[5][8],label="aktuell Infizierte")
plt.legend()
plt.show()

# %%
update_rki_data_arrays(38,7)
# Out:
# 136626

# %%
initial_compartment_distribution(38,"2020/07/24")
# Out:
# array([[ 9.98411991e-01,  6.52606620e-05,  1.49011845e-03,
#          3.26303310e-05],
#        [ 9.98495558e-01,  0.00000000e+00,  1.40509240e-03,
#          9.93499674e-05],
#        [ 9.98070320e-01,  2.20115634e-05,  1.70222757e-03,
#          2.05441258e-04],
#        [ 9.97311962e-01,  3.56503697e-05,  2.51691610e-03,
#          1.35471405e-04],
#        [ 9.98858525e-01,  1.51188721e-05,  1.08855879e-03,
#          3.77971803e-05],
#        [ 9.96012771e-01,  3.37380882e-05,  3.71118970e-03,
#          2.42300815e-04],
#        [ 9.98776429e-01,  0.00000000e+00,  1.20013126e-03,
#          2.34400638e-05],
#        [ 9.98192293e-01,  6.75778412e-05,  1.60919734e-03,
#          1.30932067e-04],
#        [ 9.98021144e-01,  6.43128175e-05,  1.87001885e-03,
#          4.45242583e-05],
#        [ 9.97674627e-01,  9.93749317e-06,  2.15643602e-03,
#          1.58999891e-04],
#        [ 9.98390097e-01, -9.99940004e-06,  1.49991001e-03,
#          1.19992800e-04],
#        [ 9.99184809e-01,  2.39762156e-05,  7.67238899e-04,
#          2.39762156e-05],
#        [ 9.97546484e-01,  4.40751351e-05,  2.30054921e-03,
#          1.08891510e-04],
#        [ 9.98922823e-01,  5.70269928e-05,  9.75795210e-04,
#          4.43543277e-05],
#        [ 9.99030623e-01,  2.69271419e-05,  9.02059253e-04,
#          4.03907128e-05],
#        [ 9.97706567e-01,  7.76947116e-05,  2.12941061e-03,
#          8.63274573e-05],
#        [ 9.98288424e-01,  2.15443080e-04,  1.47817891e-03,
#          1.79535900e-05],
#        [ 9.92826179e-01,  2.41136851e-04,  6.87514043e-03,
#          5.75440212e-05],
#        [ 9.97570158e-01,  6.49690260e-05,  2.25442520e-03,
#          1.10447344e-04],
#        [ 9.98664612e-01,  3.31361731e-05,  1.27574266e-03,
#          2.65089385e-05],
#        [ 9.97301532e-01,  1.77074953e-04,  2.44825369e-03,
#          7.31396544e-05],
#        [ 9.98746851e-01,  1.02297866e-04,  1.11888291e-03,
#          3.19680831e-05],
#        [ 9.96744085e-01,  1.33575996e-04,  2.90527792e-03,
#          2.17060994e-04],
#        [ 9.97340932e-01,  4.97022010e-05,  2.42712415e-03,
#          1.82241404e-04],
#        [ 9.99218317e-01,  4.20259889e-05,  7.22847009e-04,
#          1.68103955e-05],
#        [ 9.99218935e-01,  7.10059172e-05,  6.39053254e-04,
#          7.10059172e-05],
#        [ 9.99100086e-01,  0.00000000e+00,  8.41223883e-04,
#          5.86900383e-05],
#        [ 9.99258880e-01,  4.04247292e-05,  7.00695305e-04,
#          0.00000000e+00],
#        [ 9.99481259e-01,  6.66953210e-05,  4.37224882e-04,
#          1.48211824e-05],
#        [ 9.99608724e-01,  1.58625248e-05,  3.75413087e-04,
#          0.00000000e+00],
#        [ 9.98871888e-01,  1.01024983e-04,  1.00604045e-03,
#          2.10468714e-05],
#        [ 9.98976147e-01,  6.43564646e-05,  8.83438741e-04,
#          7.60576400e-05],
#        [ 9.98433683e-01,  2.19065249e-05,  1.53345674e-03,
#          1.09532624e-05],
#        [ 9.96984828e-01,  1.60809192e-05,  2.58098753e-03,
#          4.18103899e-04],
#        [ 9.98403304e-01,  8.35966628e-06,  1.47130127e-03,
#          1.17035328e-04],
#        [ 9.96984828e-01,  1.60809192e-05,  2.58098753e-03,
#          4.18103899e-04],
#        [ 9.98408300e-01,  5.75313306e-05,  1.44787182e-03,
#          8.62969959e-05],
#        [ 9.98768555e-01,  2.96733704e-05,  1.11275139e-03,
#          8.90201111e-05]])

# %%
save_initial_compartment_distribution(38, "2020/07/24")
